# %% [markdown]
# # Best Cat - Octocat
#
#
# <img src="https://alexandruturcanu.com/images/faces/octocat.png" width=200px>
# <!-- [Cat](https://alexandruturcanu.com/images/faces/octocat.png) -->

# %% [markdown]
# ### Docs
#
# A _simple_ function to add to numbers

# %%
def sum(a: int, b: int):
    return a + b

# %%
sum(5, 7)
# Out:
# 12

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")

# %%
ls_age = df['Age'].dropna()
print(f"Average Age: {ls_age.mean()}")
# Out:
# Average Age: 29.69911764705882

# %%
ls_sex = df['Sex']
female_count = 0
for passenger in ls_sex:
    if passenger == 'female':
        female_count += 1

female_percentage = female_count / len(ls_sex)
print(f"Female Percentage: {female_percentage}")
# Out:
# Female Percentage: 0.35241301907968575

# %%
df['Sex'].value_counts(normalize=True) * 100
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(ls_age, bins=10)
plt.xlabel("Ages")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sbs

sbs.distplot(ls_age, kde=True, hist="True")

# %%
ls = df["Survived"]
number_survivors = len(ls.where(ls > 0).dropna())
ratio = number_survivors / len(ls)
print(ratio)
# Out:
# 0.3838383838383838

# %%
df_survivors = df.loc[df["Survived"] == 1]
ls_age = df["Age"].dropna()
mean = ls_age.mean() # 29.69
median = ls_age.median() # 18
std = ls_age.std() # 14.52
# Out:
# 29.69911764705882
